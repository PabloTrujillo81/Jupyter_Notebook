# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Pablo Jesus Trujillo Serrano </b>

# %% [markdown]
# <i> I am interested in data science because it helps be with my current job. </i>
# <i> It gives me the tools to understand the testing and modelling data in a much efficient way than I currently do. </i>

# %% [markdown]
# ### This code calculates how many wine bottles can be filled with a bordeleaise wine barrel

# %%
barrel=225
print("Wine barrel contains "+ str(barrel) + " liter") 
bottle=0.7
print("Wine bottle contains "+ str(bottle) + " liter") 
numberOfBottles=barrel/bottle
print("Wine barrel contains " + str(numberOfBottles) + " bottles")
# Out:
# Wine barrel contains 225 liter
# Wine bottle contains 0.7 liter
# Wine barrel contains 321.42857142857144 bottles

# %% [markdown]
# <ul>
#     <li> Bullet list element 1 </li>
#     <li> Bullet list element 2 </li>
# </ul>
#
# <ol>
#     <li> Numbered list element 1 </li>
#     <li> Numbered list element 2 </li>
# </ol>
#
# | Name | Age |
# | --- | ----------- |
# | Pepe | 21 |
# | Paco | 30 |
# | Jose | 35 |
# | Francisco | 40 |
#
# [IBM Website](https://www.ibm.com/)
#
#
# I need to highlight that <mark>I am enjoying this course</mark>.
#
# >This is my blocked quote 1
# >
# >This is my blocked quote 2
